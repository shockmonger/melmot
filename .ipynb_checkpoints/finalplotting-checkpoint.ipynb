# %%
# %matplotlib notebook

# %%
# %run dataset.py
# %run funcs.py

# %%
import seaborn as sns
sns.set_style("whitegrid")
ax = sns.violinplot(x=avdataset['genre'],y=avdataset['handstrat'],hue=avdataset['sex'], 
                    split = True,inner="quart",palette='pastel', color_codes=True)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig,ax = plt.subplots()
x = avdataset['participant']
y = avdataset['zmin']
sns.violinplot(x, y, lowess=True, color="g")
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-42fbab3b7d58> in <module>()
#       2 x = avdataset['participant']
#       3 y = avdataset['zmin']
# ----> 4 sns.violinplot(x, y, lowess=True, color="g")
#
# NameError: name 'sns' is not defined

# %%
# pitches[0]

# %%
f, ax = plt.subplots(3,2,sharex=True,sharey=True,figsize = (16,10))
for i in range(4):
    ax[0,0].plot(pitches[3])
    ax[0,0].set_title('M4 - a Small Object')
    ax[1,0].plot(pitches[15])
    ax[1,0].set_title('M16 - inter-palm distance')
    ax[2,0].plot(pitches[12])
    ax[2,0].set_title('M13 - symmetrical hand movement')
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
pitches = []
names = []
im = [1,2,3,4,17,18,19,20]
jo = [5,6,7,8,21,22,23,24]
sc = [9,10,11,12,25,26,27,28]
vo = [13,14,15,16,29,30,31,32]

for i in range(1,17,1):
    strings = str(i)+'.txt'
    pitches.append(ups(readpitch(strings)['F0_Hz']))
    names.append(str(i))        

cols = ['names','pitches']
    
melodies = pd.DataFrame(zip(names,pitches))
melodies.columns = cols

# %%
# %run dataext.py

# %%
# curve fit

import numpy as np
from scipy.optimize import leastsq

p0 = [0, 0, 0, 1]

def fitfunc(p, coords):
    x0, y0, z0, R = p
    x, y, z = coords.T
    return np.sqrt((x-x0)**2 + (y-y0)**2 + (z-z0)**2)

errfunc = lambda p, x: fitfunc(p, x) - p[3]

coordinates = []
keys = []

for i in range(len(pieces)):
    coords = pd.DataFrame.as_matrix(getlhrh(pieces[i])['rh'])
    p1, flag = leastsq(errfunc, p0, args=(coords,))
    coordinates.append(p1)
    keys.append(int(i))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-9116971925f3> in <module>()
#      17
#      18 for i in range(len(pieces)):
# ---> 19     coords = pd.DataFrame.as_matrix(getlhrh(pieces[i])['rh'])
#      20     p1, flag = leastsq(errfunc, p0, args=(coords,))
#      21     coordinates.append(p1)
#
# /home/tejaswik/Documents/CurrentProjects/melmot/funcs.py in getlhrh(stri)
#      85
#      86 def getlhrh(stri):
# ---> 87     rh = readfile(stri).iloc[:,1:4]
#      88     lh = readfile(stri).iloc[:,4:7]
#      89     return{'lh':lh,'rh':rh}
#
# /home/tejaswik/Documents/CurrentProjects/melmot/funcs.py in readfile(stri)
#      46 def readfile(stri):
#      47     fil = basefile+'data/normdatadump/'+stri+'.csv'
# ---> 48     df1=pd.read_table(fil,header=0)
#      49     df1.columns=colHeads
#      50     return(df1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# IOError: File /home/tejaswik/Documents/CurrentProjects/melmot/data/normdatadump/7_14_6.csv does not exist

# %%
# spline interpolation
from scipy.interpolate import splprep

coords = pd.DataFrame.as_matrix(getlhrhn(pieces[1])['rh'])

tck,u = splprep(x=coords[:,0], w=coords[:,1], u=coords[:,2], ub=None, ue=None, 
                           k=3, task=0, s=None, t=None, full_output=0, nest=None, per=0, quiet=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f50559f36878> in <module>()
#       2 from scipy.interpolate import splprep
#       3
# ----> 4 coords = pd.DataFrame.as_matrix(getlhrhn(pieces[1])['rh'])
#       5
#       6 tck,u = splprep(x=coords[:,0], w=coords[:,1], u=coords[:,2], ub=None, ue=None,
#
# NameError: name 'getlhrhn' is not defined
