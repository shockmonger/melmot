# %%
import os
# %matplotlib notebook
# %run functions.py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = './repeats/mel00008/'
files = os.listdir(path)

# %%
files
# Out:
# ['p1.tsv',
#  'r4.tsv',
#  'r2.tsv',
#  'r1.tsv',
#  'p4.tsv',
#  'p3.tsv',
#  'r3.tsv',
#  'p2.tsv',
#  'r5.tsv']

# %%
p1 = pd.DataFrame.from_csv('./repeats/mel00008/p1.tsv',sep = '\t')
r1 = pd.DataFrame.from_csv('./repeats/mel00008/r1.tsv',sep = '\t')
plt.plot(p1.iloc[:,1],color ='red')
plt.plot(r1.iloc[:,1],color ='red')
plt.plot(p1.iloc[:,4],color ='blue')
plt.plot(r1.iloc[:,4],color ='blue')
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
f,ax = plt.subplots()
p2 = pd.DataFrame.from_csv('./repeats/mel00008/p2.tsv',sep = '\t')
r2 = pd.DataFrame.from_csv('./repeats/mel00008/r2.tsv',sep = '\t')
plt.plot(p2.iloc[:,1],color ='red')
plt.plot(r2.iloc[:,1],color ='red')
plt.plot(p2.iloc[:,4],color ='blue')
plt.plot(r2.iloc[:,4],color ='blue')
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
f,ax = plt.subplots()
p3 = pd.DataFrame.from_csv('./repeats/mel00008/p3.tsv',sep = '\t')
r3 = pd.DataFrame.from_csv('./repeats/mel00008/r3.tsv',sep = '\t')
plt.plot(p3.iloc[:,1],color ='red')
plt.plot(r3.iloc[:,1],color ='red')
plt.plot(p3.iloc[:,4],color ='blue')
plt.plot(r3.iloc[:,4],color ='blue')
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
f,ax = plt.subplots()
p4 = pd.DataFrame.from_csv('./repeats/mel00008/p4.tsv',sep = '\t')
r4 = pd.DataFrame.from_csv('./repeats/mel00008/r4.tsv',sep = '\t')
plt.plot(p4.iloc[:,1],color ='red')
plt.plot(r4.iloc[:,1],color ='red')
plt.plot(p4.iloc[:,4],color ='blue')
plt.plot(r4.iloc[:,4],color ='blue')
# Out:
# <img src="data:image/png;base64,..." width="639.85">
