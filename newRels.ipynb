# %%
# %run funcs.py
# %matplotlib notebook
# %run functions.py
# %run dataset.py

# %%
# %run detect_peaks.py

# %%
def settopiece(stri,y):
    s ='p'+str(y)
    eval(s).append(stri)
    return

# %%
eachtracing = dict()
pieces = os.listdir(basefile+'data/normdatadump/')        
pitches = os.listdir(basefile+'sound/pitch/')



p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18,p19,p20,p21,p22,p23,p24,p25,p26,p27,p28,p29,p30,p31,p32 = ([] for i in range(32))

for i in range(len(pieces)):
    pieces[i] = pieces[i][:-4]
    melID = returnDetails(pieces[i])['melID']
    settopiece(pieces[i],melID)

# %%
m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12,m13,m14,m15,m16,m17,m18,m19,m20,m21,m22,m23,m24,m25,m26,m27,m28,m29,m30,m31,m32 = ([] for i in range(32))

for i in range(len(contset)):
    mel = contset['melody'][i]
    v = contset['vels'][i]
    stri = 'm'+str(mel)
    eval(stri).append(contset['rz'][i])

# %%
pitches = []
names = []
im = [1,2,3,4,17,18,19,20]
jo = [5,6,7,8,21,22,23,24]
sc = [9,10,11,12,25,26,27,28]
vo = [13,14,15,16,29,30,31,32]

for i in range(1,17,1):
    strings = str(i)+'.txt'
    pitches.append(ups(readpitch(strings)['F0_Hz']))
    names.append(str(i))        

cols = ['names','pitches']
    
melodies = pd.DataFrame(zip(names,pitches))
melodies.columns = cols
# melodies.iloc[0,1]

# %%
vels= []
for i in range(len(dataset)):
    ser = dataset['rz'][i]
    vel = numpy.diff(ser)
    vels.append(vel)
    
contset['vels']=vels

# %%
fig,ax = plt.subplots()
plt.plot(x_normed)
y = numpy.diff(x)
plt.plot(y)
z = numpy.diff(y)
plt.plot(z)
j = numpy.diff(z)
plt.plot(j)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
p = detect_peaks(contset['rz'][2],show = True)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
'''add this for each item in dataset / contset'''
x = dataset['rz'][4]
x_normed = x / x.max(axis=0)

# %%
detect_peaks(z, threshold=0.5,show=True)
detect_peaks(j, threshold=0.5,show=True)
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="799.9999880790713">
# array([208, 211, 462, 464])

# %%
detect_peaks(x)
# Out:
# array([138, 182, 234, 290, 381, 464])

# %%
contset.keys()
# Out:
# Index([u'key', u'handstrat', u'participant', u'melody', u'sex', u'age',
#        u'score', u'genre', u'proc', u'lz', u'rz', u'qomvals', u'velr', u'accr',
#        u'mel', u'handdistvals', u'melcat', u'vels'],
#       dtype='object')

# %%
p1
# Out:
# ['10_1_3',
#  '9_1_4',
#  '25_1_3',
#  '11_1_2',
#  '31_1_4',
#  '32_1_3',
#  '17_1_3',
#  '13_1_4',
#  '2_1_1',
#  '20_1_1',
#  '26_1_4',
#  '16_1_3',
#  '18_1_2',
#  '6_1_1',
#  '4_1_1',
#  '22_1_4',
#  '7_1_4',
#  '8_1_3',
#  '12_1_1',
#  '30_1_4',
#  '1_1_4',
#  '14_1_2',
#  '21_1_4',
#  '5_1_3',
#  '3_1_4',
#  '28_1_2']

# %%
f, ax = plt.subplots(3,2,sharex=True,sharey=True,figsize = (16,10))
for i in range(4):
    for j in range(len(m4)):
        ax[0,0].plot(m4[j],color = 'purple',linewidth = '0.5')
        ax[0,0].plot(m20[j],color = 'grey',linewidth = '0.5')
        ax[0,0].set_title('M4 - a Small Object')
    for j in range(len(m16)):
        ax[1,0].plot(m16[j],color = 'purple',linewidth = '0.5')
        ax[1,0].plot(m32[j],color = 'grey',linewidth = '0.5')
        ax[1,0].set_title('M16 - inter-palm distance')
    for j in range(len(m29)):
        ax[2,0].plot(m13[j],color = 'purple',linewidth = '0.5')
        ax[2,0].plot(m29[j],color = 'grey',linewidth = '0.5')
        ax[2,0].set_title('M13 - symmetrical hand movement')
# Out:
# <img src="data:image/png;base64,..." width="1599.9999761581425">

# %%
m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12,m13,m14,m15,m16,m17,m18,m19,m20,m21,m22,m23,m24,m25,m26,m27,m28,m29,m30,m31,m32 = ([] for i in range(32))


for i in range(len(contset)):
    mel = contset['melody'][i]
#     v = contset['lz'][i]
    stri = 'm'+str(mel)
    eval(stri).append(contset['handdistvals'][i])

f,a = plt.subplots()
for i in range(len(m16)):
    plt.plot(m16[i])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f,a = plt.subplots()
for i in range(len(m2)):
    plt.plot(m2[i])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#plt.plot(vels[1])

# %%
#plt.plot(numpy.diff(vels[1]))

# %%
pitches = []
names = []
im = [1,2,3,4,17,18,19,20]
jo = [5,6,7,8,21,22,23,24]
sc = [9,10,11,12,25,26,27,28]
vo = [13,14,15,16,29,30,31,32]

for i in range(1,17,1):
    strings = str(i)+'.txt'
    pitches.append(ups(readpitch(strings)['F0_Hz']))
    names.append(str(i))        

cols = ['names','pitches']
    
melodies = pd.DataFrame(zip(names,pitches))
melodies.columns = cols
# melodies.iloc[0,1]

# %%
for i in range(12,16,1):
    pitches[i][0] = 2*pitches[i][0]

# %%
maxes = []
for i in range(16):
    maxes.append(max(pitches[i][0]))

# %%
maxes
# Out:
# [224.73890439487326,
#  320.86581894822871,
#  192.82065687853941,
#  255.22039160943322,
#  353.30938793171049,
#  277.02301177137184,
#  432.48362063408479,
#  407.40365499103291,
#  487.16930175537487,
#  492.79131804952306,
#  644.98215418163113,
#  501.4020911941526,
#  1010.2942535129006,
#  889.38035380786994,
#  592.9254777472521,
#  1005.3913143269933]

# %%
means = []
for i in range(16):
    means.append(np.mean(pitches[i][0]))

# %%
means
# Out:
# [180.06449892427622,
#  178.39134184322037,
#  177.3764350095785,
#  209.73799085781997,
#  275.4196318909091,
#  214.98579850717701,
#  283.21126159139783,
#  298.94599885245901,
#  230.52771042368423,
#  319.50121645000002,
#  417.20465070560732,
#  414.19889841150439,
#  696.13632315044242,
#  745.96199254469855,
#  507.26456464541843,
#  836.2371400684209]

# %%
pitches = pd.DataFrame(pitches)

# %%
pitches.columns = ['values']

# %%
pitches['melody'] = pitches.index
pitches['melody'] = pitches['melody']+1

# %%
pitches['max'] = maxes
pitches['mean'] = means
pitches['genre'] = ['im','im','im','im','jo','jo','jo','jo','sc','sc','sc','sc','vo','vo','vo','vo']

# %%
pitches['singer'] = ['m','m','m','m','f','f','f','f','m','m','m','m','f','f','f','f']

# %%
pitches['dirch'] = ['n','n','y','y','n','y','y','y','n','y','n','y','y','n','n','y']

# %%
pitches
# Out:
#                                                values  melody          max  \
# 0                 0
# 0    149.953407
# 1    149.94144...       1   224.738904
# 1                 0
# 0    160.888612
# 1    141.88633...       2   320.865819
# 2                 0
# 0    189.591800
# 1    191.00921...       3   192.820657
# 3                 0
# 0    214.205007
# 1    221.56683...       4   255.220392
# 4                 0
# 0    255.027198
# 1    247.67223...       5   353.309388
# 5                 0
# 0    101.126622
# 1     94.17632...       6   277.023012
# 6                 0
# 0    285.163078
# 1    283.41233...       7   432.483621
# 7                 0
# 0    237.864488
# 1    230.73741...       8   407.403655
# 8                 0
# 0    122.387140
# 1    115.15932...       9   487.169302
# 9                 0
# 0    270.991061
# 1    268.18451...      10   492.791318
# 10                0
# 0    591.130618
# 1    644.98215...      11   644.982154
# 11                0
# 0    459.816538
# 1    495.73617...      12   501.402091
# 12                0
# 0    347.030231
# 1    342.70328...      13  1010.294254
# 13                0
# 0    874.859024
# 1    889.38035...      14   889.380354
# 14                0
# 0    535.184488
# 1    524.57120...      15   592.925478
# 15                0
# 0    561.927984
# 1    546.85495...      16  1005.391314
#
#           mean genre
# 0   180.064499    im
# 1   178.391342    im
# 2   177.376435    im
# 3   209.737991    im
# 4   275.419632    jo
# 5   214.985799    jo
# 6   283.211262    jo
# 7   298.945999    jo
# 8   230.527710    sc
# 9   319.501216    sc
# 10  417.204651    sc
# 11  414.198898    sc
# 12  696.136323    vo
# 13  745.961993    vo
# 14  507.264565    vo
# 15  836.237140    vo

# %%
import seaborn as sns
sns.set_style("whitegrid")             

paper_rc = {'lines.linewidth': 1, 'lines.markersize': 10}     
fig,ax =plt.subplots(figsize=(16, 10))
ax.set(yscale="log")
ax = sns.violinplot(x=pitches['genre'],y=pitches['max'],hue =pitches['dirch'],
                     split = True,inner="quart",scale="count",bw=.5,palette="RdBu")
plt.xlabel('Genre: Hindustani Music, Joik, Scat, Vocalise',fontsize='32')
plt.ylabel('Maximum Frequency of all melodies (Hz)',fontsize = '28')
plt.setp(ax.get_legend().get_texts(), fontsize='28') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='2') # for legend title
# Out:
# <img src="data:image/png;base64,..." width="1599.9999761581425">
# [None, None]
