# %%
'''splines as feature'''
# %run functions.py
# %matplotlib notebook
# %run dataset.py

# %%
# %run dataset.py
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/tejaswik/Documents/CurrentProjects/melmot/dataset.py in <module>()
#      15 for i in range(len(tracings)):
#      16     key.append(i)
# ---> 17     handstrat.append(returnDetails(tracings[i])['typeID'])
#      18     partic = int(returnDetails(tracings[i])['partID'])-1
#      19     participant.append(partic)
#
# /home/tejaswik/Documents/CurrentProjects/melmot/funcs.py in returnDetails(string)
#     152     split = string.split('_')
#     153     partID = split[0]
# --> 154     melID = split[1]
#     155     typeID = split[2]
#     156     return{'partID':partID, 'melID':melID, 'typeID':typeID}
#
# IndexError: list index out of range

# %%
print(i)
partic = returnDetails(tracings[0])['partID']
partic
tracings[i]
# Out:
# 588
# '14Oct.i'

# %%
participants = pd.read_table('/home/tejaswik/Documents/CurrentProjects/melmot/participants.csv',sep=';')
participants
# Out:
#     ID sex  age  scoreMus
# 0    1   F   26       175
# 1    2   M   23       465
# 2    3   F   53       989
# 3    4   F   29       972
# 4    5   M   26       958
# 5    6   M   30       563
# 6    7   M   37       973
# 7    8   M   25       839
# 8    9   F   20       262
# 9   10   F   31       913
# 10  11   F   24       438
# 11  12   M   25       702
# 12  13   F   27       100
# 13  14   F   31       995
# 14  15   M   28       829
# 15  16   F   31       912
# 16  17   M   35       950
# 17  18   F   31       325
# 18  19   M   30       992
# 19  20   M   34       467
# 20  21   F   20       499
# 21  22   F   49       965
# 22  23   F   28       524
# 23  24   M   33       213
# 24  25   M   24       865
# 25  26   M   64       879
# 26  27   M   34       924
# 27  28   F   29       992
# 28  29   F   41       662
# 29  30   M   33       986
# 30  31   F   23       566
# 31  32   F   24       319
